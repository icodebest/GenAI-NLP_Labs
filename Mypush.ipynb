# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/GenAI_NLP/GenAI_NLP_Labs
# Out:
# /content/drive/MyDrive/GenAI_NLP/GenAI_NLP_Labs

# %%
# !git config --global user.email "waleedusmaneng12@gmail.com"
# !git config --global user.name "icodebest"

# %%
from google.colab import userdata
GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')

if GITHUB_TOKEN:
    print("✅ GitHub token retrieved successfully (hidden for security).")
else:
    print("❌ GitHub token not found! Set it in Colab Secrets.")
# Out:
# ✅ GitHub token retrieved successfully (hidden for security).

# %%
# !git remote set-url origin https://icodebest:{GITHUB_TOKEN}@github.com/icodebest/GenAI_NLP_Labs.git

# %%
# !git lfs install
# !git lfs track "*.pth"
# !git add .gitattributes
# !git commit -m "Configured Git LFS for large files"
# !git push origin main
# Out:
# Updated git hooks.
# Git LFS initialized.
# Tracking "*.pth"
# fatal: cannot exec '.git/hooks/post-commit': Permission denied
# [main 4b39a7d] Configured Git LFS for large files
#  1 file changed, 1 insertion(+)
#  create mode 100644 .gitattributes
# fatal: cannot exec '.git/hooks/pre-push': Permission denied

# %%
# !git rm --cached seq2seq_model.pth
# !git commit -m "Removed large file seq2seq_model.pth from tracking"
# Out:
# fatal: pathspec 'seq2seq_model.pth' did not match any files
# On branch main
# Your branch is ahead of 'origin/main' by 6 commits.
#   (use "git push" to publish your local commits)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Mypush.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !pip install git-filter-repo
# !git filter-repo --path seq2seq_model.pth --invert-paths
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.3/76.3 kB 6.7 MB/s eta 0:00:00
# ...
# Aborting: Refusing to destructively overwrite repo history since
# this does not look like a fresh clone.
#   (expected freshly packed repo)
# Please operate on a fresh clone instead.  If you want to proceed
# anyway, use --force.

# %%
# !git reflog expire --expire=now --all
# !git gc --prune=now
# !git gc --aggressive --prune=now
# Out:
# Enumerating objects: 115, done.
# Counting objects: 100% (115/115), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (51/51), done.
# Writing objects: 100% (115/115), done.
# Total 115 (delta 64), reused 111 (delta 62), pack-reused 0
# Enumerating objects: 115, done.
# Counting objects: 100% (115/115), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (113/113), done.
# Writing objects: 100% (115/115), done.
# Total 115 (delta 65), reused 50 (delta 0), pack-reused 0

# %%
# !git add .
# !git commit -m "Updated project files"
# Out:
# [main 83b2c30] Updated project files
#  1 file changed, 1 insertion(+)
#  create mode 100644 Mypush.ipynb

# %%
# !git push origin main
# Out:
# Enumerating objects: 28, done.
# Counting objects: 100% (28/28), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (16/16), done.
# Writing objects: 100% (25/25), 211.27 MiB | 71.99 MiB/s, done.
# Total 25 (delta 14), reused 19 (delta 9), pack-reused 0
# remote: Resolving deltas: 100% (14/14), completed with 3 local objects.
# remote: error: Trace: 25dce39da767df8d8a79e5727d0b21c54828359c8e6849280e630b6cd5d87f9f
# remote: error: See https://gh.io/lfs for more information.
# remote: error: File seq2seq_model.pth is 240.81 MB; this exceeds GitHub's file size limit of 100.00 MB
# remote: error: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# To https://github.com/icodebest/GenAI_NLP_Labs.git
#  ! [remote rejected] main -> main (pre-receive hook declined)
# error: failed to push some refs to 'https://github.com/icodebest/GenAI_NLP_Labs.git'
